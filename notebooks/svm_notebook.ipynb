# %%
from svm import svm, linear_kernel, polynomial_kernel, gaussian_kernel, exponential_kernel, rational_quadratic_kernel, wave_kernel

# %%
#Training svm machine on vec_loan data.

# %%
# Linear Kernel
svm('../440ProjData/vec_loan.csv', True, linear_kernel)
# Out:
# ----------------------
# Accuracy:  0.813389012136239
# Precision:  0.2077562326869806
# Recall:  0.06152584085315833
# ----------------------
# Accuracy:  0.5602244551742137
# Precision:  0.18451158697565267
# Recall:  0.5159967186218212
# ----------------------
# Accuracy:  0.8003392927052069
# Precision:  0.21981981981981982
# Recall:  0.10008203445447088
# ----------------------
# Accuracy:  0.7985123319848624
# Precision:  0.18199608610567514
# Recall:  0.07629204265791632
# ----------------------
# Accuracy:  0.23515594414720084
# Precision:  0.14015503875968993
# Recall:  0.7415914684167351
# ----------------------
# Accuracy:  0.7439645047631476
# Precision:  0.26292278238672623
# Recall:  0.3379819524200164

# %%
svm('../440ProjData/vec_loan.csv', True, polynomial_kernel)
# Out:
# ----------------------
# Accuracy:  0.1701683413806603
# Precision:  0.16153744551578392
# Recall:  0.9910858995137763
# ----------------------
# Accuracy:  0.17982513375962417
# Precision:  0.16087014905331007
# Recall:  0.9708265802269044
# ----------------------
# Accuracy:  0.1819130888685893
# Precision:  0.15864406779661017
# Recall:  0.9481361426256077
# ----------------------
# Accuracy:  0.7761973117577972
# Precision:  0.23943661971830985
# Recall:  0.17909238249594814
# ----------------------
# Accuracy:  0.48766801513767455
# Precision:  0.13582251082251082
# Recall:  0.406807131280389
# ----------------------
# Accuracy:  0.7623646091609031
# Precision:  0.16985376827896512
# Recall:  0.12236628849270664

# %%
svm('../440ProjData/vec_loan.csv', True, gaussian_kernel)
# Out:
# ----------------------
# Accuracy:  0.770063943625212
# Precision:  0.17582417582417584
# Recall:  0.11697806661251016
# ----------------------
# Accuracy:  0.3067989038235678
# Precision:  0.16188898094449047
# Recall:  0.7936636880584891
# ----------------------
# Accuracy:  0.30131802166253424
# Precision:  0.16099325768788028
# Recall:  0.7952883834281073
# ----------------------
# Accuracy:  0.24155030666840663
# Precision:  0.1340469723598019
# Recall:  0.6815597075548334
# ----------------------
# Accuracy:  0.4192874853190656
# Precision:  0.13790776152980877
# Recall:  0.4979691307879773
# ----------------------
# Accuracy:  0.1917003784418635
# Precision:  0.15577750034678875
# Recall:  0.9122664500406173

# %%
svm('../440ProjData/vec_loan.csv', True, exponential_kernel)
# Out:
# ----------------------
# Accuracy:  0.23554743573013182
# Precision:  0.14177018633540373
# Recall:  0.7339228295819936
# ----------------------
# Accuracy:  0.18491452433772673
# Precision:  0.16239200863930886
# Recall:  0.9670418006430869
# ----------------------
# Accuracy:  0.35625734046717994
# Precision:  0.13683796022839143
# Recall:  0.5586816720257235
# ----------------------
# Accuracy:  0.3644786637087303
# Precision:  0.16623711340206185
# Recall:  0.7258842443729904
# ----------------------
# Accuracy:  0.663578233067989
# Precision:  0.15332640332640332
# Recall:  0.23713826366559485
# ----------------------
# Accuracy:  0.33328983426856323
# Precision:  0.1658308836244164
# Recall:  0.7709003215434084

# %%
svm('../440ProjData/vec_loan.csv', True, rational_quadratic_kernel)
# Out:
# ----------------------
# Accuracy:  0.5770585932402453
# Precision:  0.14622973925299507
# Recall:  0.33657745336577455
# ----------------------
# Accuracy:  0.6262560354952369
# Precision:  0.15164459632635627
# Recall:  0.28791565287915655
# ----------------------
# Accuracy:  0.2979250946104659
# Precision:  0.16180068504322295
# Recall:  0.8045417680454177
# ----------------------
# Accuracy:  0.8260472399843404
# Precision:  0.23958333333333334
# Recall:  0.0373073803730738
# ----------------------
# Accuracy:  0.17577972073600417
# Precision:  0.15917929462250235
# Recall:  0.9626926196269262
# ----------------------
# Accuracy:  0.7725433903171082
# Precision:  0.16796875
# Recall:  0.10462287104622871

# %%
svm('../440ProjData/vec_loan.csv', True, wave_kernel)
# Out:
# ----------------------
# Accuracy:  0.6570533733524729
# Precision:  0.2159090909090909
# Recall:  0.43322475570032576
# ----------------------
# Accuracy:  0.743703510374527
# Precision:  0.16051660516605165
# Recall:  0.14169381107491857
# ----------------------
# Accuracy:  0.604071512462482
# Precision:  0.14280063291139242
# Recall:  0.2939739413680782
# ----------------------
# Accuracy:  0.4383400756883727
# Precision:  0.13811764705882354
# Recall:  0.4780130293159609
# ----------------------
# Accuracy:  0.32010961764322066
# Precision:  0.1319778188539741
# Recall:  0.5814332247557004
# ----------------------
# Accuracy:  0.38666318674148503
# Precision:  0.1369719782517775
# Recall:  0.5333876221498371

# %%
#Training svm machine on vec_spam data.

# %%
# Linear Kernel
svm('../440ProjData/vec_spam.csv', True, linear_kernel)
# Out:
# ----------------------
# Accuracy:  0.6799013010318529
# Precision:  0.14113597246127366
# Recall:  0.2765598650927487
# ----------------------
# Accuracy:  0.48272768057424853
# Precision:  0.13350449293966624
# Recall:  0.5261382799325464
# ----------------------
# Accuracy:  0.7063705697622252
# Precision:  0.14484126984126985
# Recall:  0.24620573355817876
# ----------------------
# Accuracy:  0.680574248541947
# Precision:  0.1345646437994723
# Recall:  0.2580101180438449
# ----------------------
# Accuracy:  0.7662628981606101
# Precision:  0.13964686998394862
# Recall:  0.1467116357504216
# ----------------------
# Accuracy:  0.37931807985643784
# Precision:  0.13102511880515955
# Recall:  0.6509274873524452

# %%
svm('../440ProjData/vec_spam.csv', True, polynomial_kernel)
# Out:
# ----------------------
# Accuracy:  0.20659488559892328
# Precision:  0.1365103003226607
# Recall:  0.9046052631578947
# ----------------------
# Accuracy:  0.6792283535217586
# Precision:  0.13756613756613756
# Recall:  0.2565789473684211
# ----------------------
# Accuracy:  0.4676985195154778
# Precision:  0.13183145598664997
# Recall:  0.5197368421052632
# ----------------------
# Accuracy:  0.6325706594885598
# Precision:  0.1403631284916201
# Recall:  0.3305921052631579
# ----------------------
# Accuracy:  0.7139973082099597
# Precision:  0.13230429988974643
# Recall:  0.19736842105263158
# ----------------------
# Accuracy:  0.5605652759084792
# Precision:  0.14315900686740624
# Recall:  0.4457236842105263

# %%
svm('../440ProjData/vec_spam.csv', True, gaussian_kernel)
# Out:
# ----------------------
# Accuracy:  0.7759084791386271
# Precision:  0.1438721136767318
# Recall:  0.1354515050167224
# ----------------------
# Accuracy:  0.5549573799910273
# Precision:  0.13487881981032665
# Recall:  0.4280936454849498
# ----------------------
# Accuracy:  0.2420367877972185
# Precision:  0.13398262700710714
# Recall:  0.8511705685618729
# ----------------------
# Accuracy:  0.37079407806191117
# Precision:  0.13375373382011285
# Recall:  0.6739130434782609
# ----------------------
# Accuracy:  0.6218034993270525
# Precision:  0.13391655450874831
# Recall:  0.33277591973244147
# ----------------------
# Accuracy:  0.5320771646478242
# Precision:  0.13421828908554573
# Recall:  0.45652173913043476

# %%
svm('../440ProjData/vec_spam.csv', True, exponential_kernel)
# Out:
# ----------------------
# Accuracy:  0.5163750560789592
# Precision:  0.13921113689095127
# Recall:  0.49916805324459235
# ----------------------
# Accuracy:  0.5623598026020638
# Precision:  0.14473684210526316
# Recall:  0.45757071547420963
# ----------------------
# Accuracy:  0.2521310004486317
# Precision:  0.12937347436940602
# Recall:  0.7936772046589018
# ----------------------
# Accuracy:  0.4950650515926424
# Precision:  0.1293800539083558
# Recall:  0.47920133111480867
# ----------------------
# Accuracy:  0.5141318977119784
# Precision:  0.13989875747814082
# Recall:  0.5058236272878536
# ----------------------
# Accuracy:  0.18775235531628534
# Precision:  0.1329606222654351
# Recall:  0.9101497504159733

# %%
svm('../440ProjData/vec_spam.csv', True, rational_quadratic_kernel)
# Out:
# ----------------------
# Accuracy:  0.5706594885598923
# Precision:  0.13729849916620346
# Recall:  0.40558292282430214
# ----------------------
# Accuracy:  0.8100044863167339
# Precision:  0.13719512195121952
# Recall:  0.07389162561576355
# ----------------------
# Accuracy:  0.5338716913414087
# Precision:  0.13475882645450024
# Recall:  0.44499178981937604
# ----------------------
# Accuracy:  0.5471063257065949
# Precision:  0.13993871297242083
# Recall:  0.44991789819376027
# ----------------------
# Accuracy:  0.47330641543292956
# Precision:  0.13634462567963196
# Recall:  0.535303776683087
# ----------------------
# Accuracy:  0.408254822790489
# Precision:  0.13572710951526032
# Recall:  0.6206896551724138

# %%
svm('../440ProjData/vec_spam.csv', True, wave_kernel)
# Out:
# ----------------------
# Accuracy:  0.7200538358008075
# Precision:  0.13507377979568672
# Recall:  0.19669421487603306
# ----------------------
# Accuracy:  0.4585015702108569
# Precision:  0.1321675477836519
# Recall:  0.5371900826446281
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-0ec58157da47> in <module>
# ----> 1 svm('../440ProjData/vec_spam.csv', True, wave_kernel)
#
# ~\PycharmProjects\CSDS440-s21-3\src\svm.py in svm(data_path, online, classifier_type)
#     141                 y_train1 = y_train
#     142
# --> 143             classifier.train(x_train1.values, y_train1.values)
#     144             predicted_labels = classifier.predict(x_test.values)
#     145             Accuracy = accuracy(y_test.values, predicted_labels)
#
# ~\PycharmProjects\CSDS440-s21-3\src\svm.py in train(self, x_train, y_train)
#      65
# ...

# %%
#Training svm machine on orange_grapefruit dataset.

# %%
# Linear Kernel
svm('../440ProjData/orange_grapefruit.csv', True, linear_kernel)
# Out:
# ----------------------
# Accuracy:  0.37375
# Precision:  0.3026315789473684
# Recall:  0.18880597014925374
# ----------------------
# Accuracy:  0.6175
# Precision:  0.5678541136556404
# Recall:  0.9992537313432835
# ----------------------
# Accuracy:  0.518375
# Precision:  0.5171071501741447
# Recall:  0.6278606965174129
# ----------------------
# Accuracy:  0.51425
# Precision:  0.5084745762711864
# Recall:  1.0
# ----------------------
# Accuracy:  0.58025
# Precision:  0.5459211986681465
# Recall:  0.9788557213930348
# ----------------------
# Accuracy:  0.583
# Precision:  0.5472898230088495
# Recall:  0.9845771144278607

# %%
svm('../440ProjData/orange_grapefruit.csv', True, polynomial_kernel)
# Out:
# ----------------------
# Accuracy:  0.560125
# Precision:  0.5410735722860572
# Recall:  0.7891445722861431
# ----------------------
# Accuracy:  0.295875
# Precision:  0.06166219839142091
# Recall:  0.028764382191095547
# ----------------------
# Accuracy:  0.362875
# Precision:  0.08021390374331551
# Recall:  0.02626313156578289
# ----------------------
# Accuracy:  0.329875
# Precision:  0.02772002772002772
# Recall:  0.010005002501250625
# ----------------------
# Accuracy:  0.695375
# Precision:  0.6234382413411356
# Recall:  0.9859929964982491
# ----------------------
# Accuracy:  0.26775
# Precision:  0.14746019711902958
# Recall:  0.09729864932466233

# %%
svm('../440ProjData/orange_grapefruit.csv', True, gaussian_kernel)
# Out:
# ----------------------
# Accuracy:  0.166
# Precision:  0.12447316661983704
# Recall:  0.1107776944236059
# ----------------------
# Accuracy:  0.616375
# Precision:  0.5749274895262649
# Recall:  0.892223055763941
# ----------------------
# Accuracy:  0.2735
# Precision:  0.2171606864274571
# Recall:  0.17404351087771944
# ----------------------
# Accuracy:  0.804875
# Precision:  0.7619252256123764
# Recall:  0.886721680420105
# ----------------------
# Accuracy:  0.306125
# Precision:  0.009481668773704172
# Recall:  0.0037509377344336083
# ----------------------
# Accuracy:  0.596125
# Precision:  0.5579360289680145
# Recall:  0.9247311827956989

# %%
svm('../440ProjData/orange_grapefruit.csv', True, exponential_kernel)
# Out:
# ----------------------
# Accuracy:  0.66675
# Precision:  0.6018775007694676
# Recall:  0.9802005012531328
# ----------------------
# Accuracy:  0.7595
# Precision:  0.6765811965811965
# Recall:  0.9919799498746867
# ----------------------
# Accuracy:  0.367125
# Precision:  0.023957409050576754
# Recall:  0.006766917293233083
# ----------------------
# Accuracy:  0.519375
# Precision:  0.5602660016625104
# Recall:  0.16892230576441103
# ----------------------
# Accuracy:  0.782625
# Precision:  0.7145035258242806
# Recall:  0.9395989974937343
# ----------------------
# Accuracy:  0.5145
# Precision:  0.5067344345616265
# Recall:  0.9994987468671679

# %%
svm('../440ProjData/orange_grapefruit.csv', True, rational_quadratic_kernel)
# Out:
# ----------------------
# Accuracy:  0.23275
# Precision:  0.1172291296625222
# Recall:  0.08285212151644489
# ----------------------
# Accuracy:  0.72725
# Precision:  0.650208507089241
# Recall:  0.9786593020336429
# ----------------------
# Accuracy:  0.36725
# Precision:  0.017009847806624886
# Recall:  0.004770273663068039
# ----------------------
# Accuracy:  0.57775
# Precision:  0.5412631291774656
# Recall:  0.9962339944765253
# ----------------------
# Accuracy:  0.855
# Precision:  0.8807661181548422
# Recall:  0.8197338689430078
# ----------------------
# Accuracy:  0.7515
# Precision:  0.7586206896551724
# Recall:  0.7346221441124781

# %%
svm('../440ProjData/orange_grapefruit.csv', True, wave_kernel)
# Out:
# ----------------------
# Accuracy:  0.29375
# Precision:  0.08511697361871579
# Recall:  0.042932462967612356
# ----------------------
# Accuracy:  0.429
# Precision:  0.003395585738539898
# Recall:  0.0005021340697966357
# ----------------------
# Accuracy:  0.211875
# Precision:  0.08888101983002833
# Recall:  0.06301782575947779
# ----------------------
# Accuracy:  0.635875
# Precision:  0.5777842396045362
# Recall:  0.9977403966859152
# ----------------------
# Accuracy:  0.35925
# Precision:  0.00944206008583691
# Recall:  0.0027617373838814963
# ----------------------
# Accuracy:  0.566375
# Precision:  0.534496644295302
# Recall:  0.9997489329651017

# %%
#Training svm machine on cardio_disease data.

# %%
# Linear Kernel
svm('../440ProjData/cardio_disease.csv', True, linear_kernel)
# Out:
# ----------------------
# Accuracy:  0.5021785714285715
# Precision:  0.5027773005783657
# Recall:  0.31385165326184095
# ----------------------
# Accuracy:  0.49957142857142856
# Precision:  0.4983844378503132
# Recall:  0.2701697944593387
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-37fd8dbd1757> in <module>
#       1 # Linear Kernel
# ----> 2 svm('../440ProjData/cardio_disease.csv', True, linear_kernel)
#
# ~\PycharmProjects\CSDS440-s21-3\src\svm.py in svm(data_path, online, classifier_type)
#     141                 y_train1 = y_train
#     142
# --> 143             classifier.train(x_train1.values, y_train1.values)
#     144             predicted_labels = classifier.predict(x_test.values)
#     145             Accuracy = accuracy(y_test.values, predicted_labels)
#
# ~\PycharmProjects\CSDS440-s21-3\src\svm.py in train(self, x_train, y_train)
#      65
# ...

# %%
svm('../440ProjData/cardio_disease.csv', True, polynomial_kernel)
# Out:
# ----------------------
# Accuracy:  0.4900178571428571
# Precision:  0.49313484900724036
# Recall:  0.8720680008607704

# %%
svm('../440ProjData/cardio_disease.csv', True, gaussian_kernel)

# %%
svm('../440ProjData/cardio_disease.csv', True, exponential_kernel)

# %%
svm('../440ProjData/cardio_disease.csv', True, rational_quadratic_kernel)

# %%
svm('../440ProjData/cardio_disease.csv', True, wave_kernel)

# %%
#For the loan dataset
import matplotlib.pyplot as plt

#depth goes here
xpoints = [1, 20, 40, 60, 80, 100]


#cv accuracy goes here
ypointslinear = [0.813389012136239,0.5602244551742137,0.8003392927052069,0.7985123319848624,0.23515594414720084,0.7439645047631476]
ypointspolynomial = [0.1701683413806603,0.17982513375962417,0.1819130888685893,0.7761973117577972,0.48766801513767455,0.7623646091609031]
ypointsgaussian = [0.770063943625212,0.3067989038235678,0.30131802166253424,0.24155030666840663,0.4192874853190656,0.1917003784418635]
ypointsexponential = [0.18491452433772673,0.18491452433772673,0.35625734046717994,0.3644786637087303,0.663578233067989,0.33328983426856323]
ypointsrational = [0.5770585932402453,0.6262560354952369,0.2979250946104659,0.8260472399843404,0.17577972073600417,0.7725433903171082]
ypointswave = [0.6570533733524729,0.743703510374527,0.604071512462482,0.4383400756883727,0.32010961764322066,0.38666318674148503]

# Plotting both the curves simultaneously
plt.plot(xpoints, ypointslinear, color='r', label='linear')
plt.plot(xpoints, ypointspolynomial, color='b', label='polynomial')
plt.plot(xpoints, ypointsgaussian, color='g', label='gaussian')
plt.plot(xpoints, ypointsexponential, color='y', label='exponential')
plt.plot(xpoints, ypointsrational, color='m', label='rational')
plt.plot(xpoints, ypointswave, color='c', label='wave')

plt.xlabel("percent of data given to train")
plt.ylabel("acurracy")
plt.title("acurracy vs % for loan dataset")
plt.legend(loc="upper left")
plt.show()

# %%
#For the spam dataset
import matplotlib.pyplot as plt

#depth goes here
xpoints = [1, 20, 40, 60, 80, 100]

#cv accuracy goes here
ypointslinear = [0.6799013010318529,0.48272768057424853,0.7063705697622252,0.680574248541947,0.7662628981606101,0.37931807985643784]
ypointspolynomial = [0.20659488559892328,0.6792283535217586,0.4676985195154778,0.6325706594885598,0.7139973082099597,0.5605652759084792] 
ypointsgaussian = [0.7759084791386271,0.5549573799910273,0.2420367877972185,0.37079407806191117,0.6218034993270525,0.5320771646478242]
ypointsexponential = [0.5163750560789592,0.5623598026020638,0.2521310004486317,0.4950650515926424,0.5141318977119784,0.18775235531628534]
ypointsrational = [0.5706594885598923,0.8100044863167339,0.5338716913414087,0.5471063257065949,0.47330641543292956,0.408254822790489]
#ypointswave = 

# Plotting both the curves simultaneously
plt.plot(xpoints, ypointslinear, color='r', label='linear')
plt.plot(xpoints, ypointspolynomial, color='b', label='polynomial')
plt.plot(xpoints, ypointsgaussian, color='g', label='gaussian')
plt.plot(xpoints, ypointsexponential, color='y', label='exponential')
plt.plot(xpoints, ypointsrational, color='m', label='rational')
#plt.plot(xpoints, ypointswave, color='c', label='wave')

plt.xlabel("percent of data given to train")
plt.ylabel("acurracy")
plt.title("acurracy vs % for spam dataset")
plt.legend(loc="upper left")
plt.show()

# %%
#For the orange_grapefruit dataset.
import matplotlib.pyplot as plt

#depth goes here
xpoints = [1, 20, 40, 60, 80, 100]

#cv accuracy goes here
ypointslinear = [0.37375,0.6175,0.518375,0.51425,0.58025,0.583]
ypointspolynomial = [0.560125,0.295875,0.362875,0.329875,0.695375,0.26775]
ypointsgaussian = [0.166,0.616375,0.2735,0.804875,0.306125,0.596125]
ypointsexponential = [0.66675,0.7595,0.367125,0.519375,0.782625,0.5145]
ypointsrational = [0.23275,0.72725,0.36725,0.57775,0.855,0.7515]
ypointswave = [0.29375,0.429,0.211875,0.635875,0.35925,0.566375]

# Plotting both the curves simultaneously
plt.plot(xpoints, ypointslinear, color='r', label='linear')
plt.plot(xpoints, ypointspolynomial, color='b', label='polynomial')
plt.plot(xpoints, ypointsgaussian, color='g', label='gaussian')
plt.plot(xpoints, ypointsexponential, color='y', label='exponential')
plt.plot(xpoints, ypointsrational, color='m', label='rational')
plt.plot(xpoints, ypointswave, color='c', label='wave')

plt.xlabel("percent of data given to train")
plt.ylabel("acurracy")
plt.title("acurracy vs % for orange_grapefruit dataset")
plt.legend(loc="upper left")
plt.show()

# %%
#For the cardio_disease dataset
import matplotlib.pyplot as plt

#depth goes here
xpoints = [1, 20, 40, 60, 80, 100]

#cv accuracy goes here
ypointslinear = 
ypointspolynomial = 
ypointsgaussian = 
ypointsexponential = 
ypointsrational = 
ypointswave = 

# Plotting both the curves simultaneously
plt.plot(xpoints, ypointslinear, color='r', label='linear')
plt.plot(xpoints, ypointspolynomial, color='b', label='polynomial')
plt.plot(xpoints, ypointsgaussian, color='g', label='gaussian')
plt.plot(xpoints, ypointsexponential, color='y', label='exponential')
plt.plot(xpoints, ypointsrational, color='m', label='rational')
plt.plot(xpoints, ypointswave, color='c', label='wave')

plt.xlabel("percent of data given to train")
plt.ylabel("acurracy")
plt.title("acurracy vs % for cardio_disease dataset")
plt.legend(loc="upper left")
plt.show()
